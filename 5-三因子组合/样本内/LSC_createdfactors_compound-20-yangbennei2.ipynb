# %%
from jaqs_fxdayu.util import dp
from jaqs.data.dataapi import DataApi



api = DataApi(addr='tcp://data.tushare.org:8910')
api.login("13662241013", 
          'eyJhbGciOiJIUzI1NiJ9.eyJjcmVhdGVfdGltZSI6IjE1MTc2NDQzMzg5MTIiLCJpc3MiOiJhdXRoMCIsImlkIjoiMTM2NjIyNDEwMTMifQ.sVIzI5VLqq8fbZCW6yZZW0ClaCkcZpFqpiK944AHEow'
)

start = 20100101
end = 20170101

SZ_id = dp.index_cons(api, "000906.SH", start, end)

stock_symbol = list(set(SZ_id.symbol))

# %%
factor_list = ['volume', 'pb', 'roe']
check_factor = ','.join(factor_list)

# %%
import jaqs_fxdayu
jaqs_fxdayu.patch_all()
from jaqs_fxdayu.data import DataView
from jaqs.data import RemoteDataService
import jaqs_fxdayu
jaqs_fxdayu.patch_all()
from jaqs.data import DataView
from jaqs.data import RemoteDataService
from jaqs_fxdayu.data.dataservice import LocalDataService
import os
import numpy as np
import warnings
warnings.filterwarnings("ignore")

dataview_folder = '../data'
dv = DataView()
ds = LocalDataService(fp=dataview_folder)

dv_props = {'start_date': start, 'end_date': end, 'symbol':','.join(stock_symbol),
         'fields': check_factor,
         'freq': 1,
         "prepare_fields": True}

dv.init_from_config(dv_props, data_api=ds)
dv.prepare_data()
# Out:
# C:\Users\dell\Anaconda3\lib\importlib\__init__.py:126: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   return _bootstrap._gcd_import(name[level:], package, level)
# C:\Users\dell\Anaconda3\lib\site-packages\jaqs-0.6.12-py3.6.egg\jaqs\research\signaldigger\plotting.py:10: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "C:\Users\dell\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\dell\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\dell\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\dell\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "C:\Users\dell\Anaconda3\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Users\dell\Anaconda3\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Users\dell\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\dell\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Users\dell\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\dell\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\dell\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\dell\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\dell\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\dell\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\dell\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\dell\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\dell\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\dell\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\dell\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-26e843206aeb>", line 1, in <module>
#     from jaqs_fxdayu.util import dp
#   File "C:\Users\dell\Anaconda3\lib\site-packages\jaqs_fxdayu\__init__.py", line 4, in <module>
#     import matplotlib.pyplot  # 防止被JAQS重载
#   File "C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\pyplot.py", line 72, in <module>
#     from matplotlib.backends import pylab_setup
#   File "C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\backends\__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   mpl.use('Agg')
# C:\Users\dell\Anaconda3\lib\site-packages\jaqs_fxdayu\patch_util\__init__.py:41: UserWarning: jaqs_fxdayu.patch method should be called only once!
#   warnings.warn("jaqs_fxdayu.patch method should be called only once!")
# Initialize config success.
# Query data...
# Query data - query...
# NOTE: price adjust method is [post adjust]
# 当前请求daily...
# {'adjust_mode': None, 'fields': 'trade_date,high,volume,high_adj,low_adj,vwap,open_adj,trade_status,close_adj,close,open,symbol,vwap_adj,low'}
# 下载进度287/1336.
# 下载进度574/1336.
# 下载进度861/1336.
# 下载进度1148/1336.
# 当前请求daily...
# {'adjust_mode': 'post', 'fields': 'high,vwap,close,open,low,symbol,trade_date'}
# 下载进度287/1336.
# 下载进度574/1336.
# 下载进度861/1336.
# 下载进度1148/1336.
# 当前请求query_lb_dailyindicator...
# {'fields': 'symbol,pb,trade_date'}
# 下载进度287/1336.
# 下载进度574/1336.
# 下载进度861/1336.
# 下载进度1148/1336.
# Query data - daily fields prepared.
# WARNING: some data is unavailable:
#     At fields 600607.SH
# Query data - quarterly fields prepared.
# Query instrument info...
# Query adj_factor...
# Data has been successfully prepared.

# %%
dv.add_field('sw1')
sw1 = dv.get_ts('sw1')
dict_classify = {'480000': '银行', '430000': '房地产', '460000': '休闲服务', '640000': '机械设备', '240000': '有色金属', '510000': '综合', '410000': '公用事业', '450000': '商业贸易', '730000': '通信', '330000': '家用电器', '720000': '传媒', '630000': '电气设备', '270000': '电子', '490000': '非银金融', '370000': '医药生物', '710000': '计算机', '280000': '汽车', '340000': '食品饮料', '220000': '化工', '210000': '采掘', '230000': '钢铁', '650000': '国防军工', '110000': '农林牧渔', '420000': '交通运输', '620000': '建筑装饰', '350000': '纺织服装', '610000': '建筑材料', '360000': '轻工制造'}
sw1_name = sw1.replace(dict_classify)

# %%
import talib as ta
import numpy as np
import pandas as pd
from datetime import datetime

def change_time(df):
    df.index = pd.Index(map(lambda x: datetime.strptime(str(x),"%Y%m%d") , df.index))
    return df

# %%
dv.add_formula('a',
                          'close/Delay(close,1)-1',
                          is_quarterly=False, add_data=True)
dv.add_formula('b',
                          '(close/Delay(close,19))^(1/20)-1',
                          is_quarterly=False, add_data=True)
factor1= dv.add_formula('factor1',
                          '-Log((Ts_Sum(If(a>b,1,0),60)-1)*Ts_Sum(If(a<b,(a-b)^2,0),60)/(Ts_Sum(If(a<b,1,0),60))*Ts_Sum(If(a>b,(a-b)^2,0),60))',
                          is_quarterly=False, add_data=True)

# %%
factor2 = dv.add_formula('factor2','-VOL240-5*VOL5',is_quarterly=False, add_data=True)
# Out:
# Variable [VOL240] is not recognized (it may be wrong),try to fetch from the server...
# Query data - query...
# 当前请求query...
# {'fields': 'VOL240', 'view': 'factor'}
# 下载进度287/1336.
# 下载进度574/1336.
# 下载进度861/1336.
# 下载进度1148/1336.
# Query data - daily fields prepared.
# Variable [VOL5] is not recognized (it may be wrong),try to fetch from the server...
# Query data - query...
# 当前请求query...
# {'fields': 'VOL5', 'view': 'factor'}
# 下载进度287/1336.
# 下载进度574/1336.
# 下载进度861/1336.
# 下载进度1148/1336.
# Query data - daily fields prepared.

# %%
factor5 = dv.add_formula('factor5','-WVAD*VOL60',is_quarterly=False, add_data=True)
# Out:
# Variable [WVAD] is not recognized (it may be wrong),try to fetch from the server...
# Query data - query...
# 当前请求query...
# {'fields': 'WVAD', 'view': 'factor'}
# 下载进度287/1336.
# 下载进度574/1336.
# 下载进度861/1336.
# 下载进度1148/1336.
# Query data - daily fields prepared.
# Variable [VOL60] is not recognized (it may be wrong),try to fetch from the server...
# Query data - query...
# 当前请求query...
# {'fields': 'VOL60', 'view': 'factor'}
# 下载进度287/1336.
# 下载进度574/1336.
# 下载进度861/1336.
# 下载进度1148/1336.
# Query data - daily fields prepared.

# %%
factor7= dv.add_formula('factor7',
                        '-(close_adj/Ts_Sum(close_adj,120)*120-1)*100',
                        is_quarterly=False, add_data=True)

# %%
return_create = dv.add_formula('return_create','close/Delay(close,10)',is_quarterly=False, add_data=True)
factor8 = dv.add_formula('factor8','-VOL60*(return_create)',is_quarterly=False, add_data=True)

# %%
return_create = dv.add_formula('return_create','close/Delay(close,10)',is_quarterly=False, add_data=True)
factor10 = dv.add_formula('factor10','-Ts_Sum(Max(return_create,0),5)*VOL5',is_quarterly=False, add_data=True)
# Out:
# Field [return_create] is overwritten.

# %%
factor3 = dv.add_formula('factor3','-TOBT*BullPower',is_quarterly=False, add_data=True)
# Out:
# Variable [TOBT] is not recognized (it may be wrong),try to fetch from the server...
# Query data - query...
# 当前请求query...
# {'fields': 'TOBT', 'view': 'factor'}
# 下载进度287/1336.
# 下载进度574/1336.
# 下载进度861/1336.
# 下载进度1148/1336.
# Query data - daily fields prepared.
# Variable [BullPower] is not recognized (it may be wrong),try to fetch from the server...
# Query data - query...
# 当前请求query...
# {'fields': 'BullPower', 'view': 'factor'}
# 下载进度287/1336.
# 下载进度574/1336.
# 下载进度861/1336.
# 下载进度1148/1336.
# Query data - daily fields prepared.

# %%
EMA=dv.get_ts('close').ewm(span=5, adjust=False).mean()
EMA2=EMA.ewm(span=5, adjust=False).mean()
EMA3=EMA2.ewm(span=5, adjust=False).mean()
dv.append_df(EMA3,'EMA3')
factor4= dv.add_formula('factor4','-EMA3/Delay(EMA3,1)+1',is_quarterly=False, add_data=True)

# %%
factor6 = dv.add_formula('factor6','SFY12P/ASSI',is_quarterly=False, add_data=True)
# Out:
# Variable [SFY12P] is not recognized (it may be wrong),try to fetch from the server...
# Query data - query...
# 当前请求query...
# {'fields': 'SFY12P', 'view': 'factor'}
# 下载进度287/1336.
# 下载进度574/1336.
# 下载进度861/1336.
# 下载进度1148/1336.
# Query data - daily fields prepared.
# Variable [ASSI] is not recognized (it may be wrong),try to fetch from the server...
# Query data - query...
# 当前请求query...
# {'fields': 'ASSI', 'view': 'factor'}
# 下载进度287/1336.
# 下载进度574/1336.
# 下载进度861/1336.
# 下载进度1148/1336.
# Query data - daily fields prepared.

# %%
alpha_signal = ['factor1','factor2','factor3','factor4','factor5','factor6','factor7','factor8','factor10']
for a in alpha_signal:
    print((dv.get_ts(a)).shape)
# Out:
# (1700, 1336)
# (1700, 1336)
# (1700, 1336)
# (1700, 1336)
# (1700, 1336)
# (1700, 1336)
# (1700, 1336)
# (1700, 1336)
# (1700, 1336)

# %%
dv.add_field('index_member')
mask = dv.get_ts('index_member')==0
# Out:
# Query data - query...
# NOTE: price adjust method is [post adjust]
# 当前请求daily...
# {'adjust_mode': None, 'fields': 'index_member,trade_status,trade_date,symbol'}
# 下载进度287/1336.
# 下载进度574/1336.
# 下载进度861/1336.
# 下载进度1148/1336.
# Query data - daily fields prepared.

# %%
import matplotlib.pyplot as plt
from jaqs_fxdayu.research import SignalDigger
from jaqs_fxdayu.util import dp

def limit_up_down():
    # 定义可买卖条件——未停牌、未涨跌停
    trade_status = dv.get_ts('trade_status')
    mask_sus = trade_status == 0
    # 涨停
    dv.remove_field('up_limit')
    dv.add_formula('up_limit', '(close - Delay(close, 1)) / Delay(close, 1) > 0.095', is_quarterly=False, add_data=True)
    # 跌停
    dv.remove_field('down_limit')
    dv.add_formula('down_limit', '(close - Delay(close, 1)) / Delay(close, 1) < -0.095', is_quarterly=False, add_data=True)
    can_enter = np.logical_and(dv.get_ts('up_limit') < 1, ~mask_sus) # 未涨停未停牌
    can_exit = np.logical_and(dv.get_ts('down_limit') < 1, ~mask_sus) # 未跌停未停牌
    return can_enter,can_exit

def cal_obj(signal, name, period=5, quantile=5):
    obj = SignalDigger()
    obj.process_signal_before_analysis(signal,
                                       price=price,
                                       n_quantiles=quantile,
                                       period=period,
                                       can_enter = can_enter,
                                       can_exit = can_exit,
                                       mask=mask,
                                       )
    obj.create_full_report()
    return obj


can_enter,can_exit = limit_up_down()
# Out:
# Field name [up_limit] does not exist. Stop remove_field.
# Field name [down_limit] does not exist. Stop remove_field.

# %%
print(mask.shape)
print(can_enter.shape)
print(mask)
# Out:
# (1700, 1336)
# (1700, 1336)
# symbol      000001.SZ  000002.SZ  000005.SZ  000006.SZ  000008.SZ  000009.SZ  \
# trade_date
# 20100104        False      False      False      False      False      False
# 20100105        False      False      False      False      False      False
# 20100106        False      False      False      False      False      False
# 20100107        False      False      False      False      False      False
# 20100108        False      False      False      False      False      False
# 20100111        False      False      False      False      False      False
# 20100112        False      False      False      False      False      False
# 20100113        False      False      False      False      False      False
# 20100114        False      False      False      False      False      False
# 20100115        False      False      False      False      False      False
# 20100118        False      False      False      False      False      False
# 20100119        False      False      False      False      False      False
# 20100120        False      False      False      False      False      False
# 20100121        False      False      False      False      False      False
# 20100122        False      False      False      False      False      False
# 20100125        False      False      False      False      False      False
# 20100126        False      False      False      False      False      False
# 20100127        False      False      False      False      False      False
# 20100128        False      False      False      False      False      False
# 20100129        False      False      False      False      False      False
# 20100201        False      False      False      False      False      False
# 20100202        False      False      False      False      False      False
# 20100203        False      False      False      False      False      False
# 20100204        False      False      False      False      False      False
# 20100205        False      False      False      False      False      False
# 20100208        False      False      False      False      False      False
# 20100209        False      False      False      False      False      False
# 20100210        False      False      False      False      False      False
# 20100211        False      False      False      False      False      False
# 20100212        False      False      False      False      False      False
# ...               ...        ...        ...        ...        ...        ...
# 20161121        False      False      False      False      False      False
# 20161122        False      False      False      False      False      False
# 20161123        False      False      False      False      False      False
# 20161124        False      False      False      False      False      False
# 20161125        False      False      False      False      False      False
# 20161128        False      False      False      False      False      False
# 20161129        False      False      False      False      False      False
# 20161130        False      False      False      False      False      False
# 20161201        False      False      False      False      False      False
# 20161202        False      False      False      False      False      False
# 20161205        False      False      False      False      False      False
# 20161206        False      False      False      False      False      False
# 20161207        False      False      False      False      False      False
# 20161208        False      False      False      False      False      False
# 20161209        False      False      False      False      False      False
# 20161212        False      False      False      False      False      False
# 20161213        False      False      False      False      False      False
# 20161214        False      False      False      False      False      False
# 20161215        False      False      False      False      False      False
# 20161216        False      False      False      False      False      False
# 20161219        False      False      False      False      False      False
# 20161220        False      False      False      False      False      False
# 20161221        False      False      False      False      False      False
# 20161222        False      False      False      False      False      False
# 20161223        False      False      False      False      False      False
# 20161226        False      False      False      False      False      False
# 20161227        False      False      False      False      False      False
# 20161228        False      False      False      False      False      False
# 20161229        False      False      False      False      False      False
# 20161230        False      False      False      False      False      False
#
# symbol      000012.SZ  000016.SZ  000021.SZ  000022.SZ    ...      603698.SH  \
# trade_date                                                ...
# 20100104        False      False      False      False    ...          False
# 20100105        False      False      False      False    ...          False
# 20100106        False      False      False      False    ...          False
# 20100107        False      False      False      False    ...          False
# 20100108        False      False      False      False    ...          False
# 20100111        False      False      False      False    ...          False
# 20100112        False      False      False      False    ...          False
# 20100113        False      False      False      False    ...          False
# 20100114        False      False      False      False    ...          False
# 20100115        False      False      False      False    ...          False
# 20100118        False      False      False      False    ...          False
# 20100119        False      False      False      False    ...          False
# 20100120        False      False      False      False    ...          False
# 20100121        False      False      False      False    ...          False
# 20100122        False      False      False      False    ...          False
# 20100125        False      False      False      False    ...          False
# 20100126        False      False      False      False    ...          False
# 20100127        False      False      False      False    ...          False
# 20100128        False      False      False      False    ...          False
# 20100129        False      False      False      False    ...          False
# 20100201        False      False      False      False    ...          False
# 20100202        False      False      False      False    ...          False
# 20100203        False      False      False      False    ...          False
# 20100204        False      False      False      False    ...          False
# 20100205        False      False      False      False    ...          False
# 20100208        False      False      False      False    ...          False
# 20100209        False      False      False      False    ...          False
# 20100210        False      False      False      False    ...          False
# 20100211        False      False      False      False    ...          False
# 20100212        False      False      False      False    ...          False
# ...               ...        ...        ...        ...    ...            ...
# 20161121        False      False      False      False    ...          False
# 20161122        False      False      False      False    ...          False
# 20161123        False      False      False      False    ...          False
# 20161124        False      False      False      False    ...          False
# 20161125        False      False      False      False    ...          False
# 20161128        False      False      False      False    ...          False
# 20161129        False      False      False      False    ...          False
# 20161130        False      False      False      False    ...          False
# 20161201        False      False      False      False    ...          False
# 20161202        False      False      False      False    ...          False
# 20161205        False      False      False      False    ...          False
# 20161206        False      False      False      False    ...          False
# 20161207        False      False      False      False    ...          False
# 20161208        False      False      False      False    ...          False
# 20161209        False      False      False      False    ...          False
# 20161212        False      False      False      False    ...          False
# 20161213        False      False      False      False    ...          False
# 20161214        False      False      False      False    ...          False
# 20161215        False      False      False      False    ...          False
# 20161216        False      False      False      False    ...          False
# 20161219        False      False      False      False    ...          False
# 20161220        False      False      False      False    ...          False
# 20161221        False      False      False      False    ...          False
# 20161222        False      False      False      False    ...          False
# 20161223        False      False      False      False    ...          False
# 20161226        False      False      False      False    ...          False
# 20161227        False      False      False      False    ...          False
# 20161228        False      False      False      False    ...          False
# 20161229        False      False      False      False    ...          False
# 20161230        False      False      False      False    ...          False
#
# symbol      603699.SH  603766.SH  603806.SH  603866.SH  603868.SH  603883.SH  \
# trade_date
# 20100104        False      False      False      False      False      False
# 20100105        False      False      False      False      False      False
# 20100106        False      False      False      False      False      False
# 20100107        False      False      False      False      False      False
# 20100108        False      False      False      False      False      False
# 20100111        False      False      False      False      False      False
# 20100112        False      False      False      False      False      False
# 20100113        False      False      False      False      False      False
# 20100114        False      False      False      False      False      False
# 20100115        False      False      False      False      False      False
# 20100118        False      False      False      False      False      False
# 20100119        False      False      False      False      False      False
# 20100120        False      False      False      False      False      False
# 20100121        False      False      False      False      False      False
# 20100122        False      False      False      False      False      False
# 20100125        False      False      False      False      False      False
# 20100126        False      False      False      False      False      False
# 20100127        False      False      False      False      False      False
# 20100128        False      False      False      False      False      False
# 20100129        False      False      False      False      False      False
# 20100201        False      False      False      False      False      False
# 20100202        False      False      False      False      False      False
# 20100203        False      False      False      False      False      False
# 20100204        False      False      False      False      False      False
# 20100205        False      False      False      False      False      False
# 20100208        False      False      False      False      False      False
# 20100209        False      False      False      False      False      False
# 20100210        False      False      False      False      False      False
# 20100211        False      False      False      False      False      False
# 20100212        False      False      False      False      False      False
# ...               ...        ...        ...        ...        ...        ...
# 20161121        False      False      False      False      False      False
# 20161122        False      False      False      False      False      False
# 20161123        False      False      False      False      False      False
# 20161124        False      False      False      False      False      False
# 20161125        False      False      False      False      False      False
# 20161128        False      False      False      False      False      False
# 20161129        False      False      False      False      False      False
# 20161130        False      False      False      False      False      False
# 20161201        False      False      False      False      False      False
# 20161202        False      False      False      False      False      False
# 20161205        False      False      False      False      False      False
# 20161206        False      False      False      False      False      False
# 20161207        False      False      False      False      False      False
# 20161208        False      False      False      False      False      False
# 20161209        False      False      False      False      False      False
# 20161212        False      False      False      False      False      False
# 20161213        False      False      False      False      False      False
# 20161214        False      False      False      False      False      False
# 20161215        False      False      False      False      False      False
# 20161216        False      False      False      False      False      False
# 20161219        False      False      False      False      False      False
# 20161220        False      False      False      False      False      False
# 20161221        False      False      False      False      False      False
# 20161222        False      False      False      False      False      False
# 20161223        False      False      False      False      False      False
# 20161226        False      False      False      False      False      False
# 20161227        False      False      False      False      False      False
# 20161228        False      False      False      False      False      False
# 20161229        False      False      False      False      False      False
# 20161230        False      False      False      False      False      False
#
# symbol      603885.SH  603899.SH  603993.SH
# trade_date
# 20100104        False      False      False
# 20100105        False      False      False
# 20100106        False      False      False
# 20100107        False      False      False
# 20100108        False      False      False
# 20100111        False      False      False
# 20100112        False      False      False
# 20100113        False      False      False
# 20100114        False      False      False
# 20100115        False      False      False
# 20100118        False      False      False
# 20100119        False      False      False
# 20100120        False      False      False
# 20100121        False      False      False
# 20100122        False      False      False
# 20100125        False      False      False
# 20100126        False      False      False
# 20100127        False      False      False
# 20100128        False      False      False
# 20100129        False      False      False
# 20100201        False      False      False
# 20100202        False      False      False
# 20100203        False      False      False
# 20100204        False      False      False
# 20100205        False      False      False
# 20100208        False      False      False
# 20100209        False      False      False
# 20100210        False      False      False
# 20100211        False      False      False
# 20100212        False      False      False
# ...               ...        ...        ...
# 20161121        False      False      False
# 20161122        False      False      False
# 20161123        False      False      False
# 20161124        False      False      False
# 20161125        False      False      False
# 20161128        False      False      False
# 20161129        False      False      False
# 20161130        False      False      False
# 20161201        False      False      False
# 20161202        False      False      False
# 20161205        False      False      False
# 20161206        False      False      False
# 20161207        False      False      False
# 20161208        False      False      False
# 20161209        False      False      False
# 20161212        False      False      False
# 20161213        False      False      False
# 20161214        False      False      False
# 20161215        False      False      False
# 20161216        False      False      False
# 20161219        False      False      False
# 20161220        False      False      False
# 20161221        False      False      False
# 20161222        False      False      False
# 20161223        False      False      False
# 20161226        False      False      False
# 20161227        False      False      False
# 20161228        False      False      False
# 20161229        False      False      False
# 20161230        False      False      False
#
# [1700 rows x 1336 columns]

# %%
from jaqs_fxdayu.research.signaldigger import multi_factor

period_list=[20]
factor_list=['factor2','factor5','factor10']
ic = dict()
factors_dict = {signal:dv.get_ts(signal) for signal in factor_list}
for period in period_list:
    ic[period]=multi_factor.get_factors_ic_df(factors_dict,
                                              price=dv.get_ts("close_adj"),
                                              high=dv.get_ts("high_adj"), # 可为空
                                              low=dv.get_ts("low_adj"),# 可为空
                                              n_quantiles=5,# quantile分类数
                                              mask=mask,# 过滤条件
                                              can_enter=can_enter,# 是否能进场
                                              can_exit=can_exit,# 是否能出场
                                              period=period,# 持有期
                                              #benchmark_price=dv.data_benchmark, # 基准价格 可不传入，持有期收益（return）计算为绝对收益
                                              commission = 0.0008,
                                              )

ic_mean_table = pd.DataFrame(data=np.nan,columns=period_list,index=factor_list)
ic_std_table = pd.DataFrame(data=np.nan,columns=period_list,index=factor_list)
ir_table = pd.DataFrame(data=np.nan,columns=period_list,index=factor_list)
for signal in factor_list:
    for period in period_list:
        ic_mean_table.loc[signal,period]=ic[period][signal].mean()
        ic_std_table.loc[signal,period]=ic[period][signal].std()
        ir_table.loc[signal,period]=ic[period][signal].mean()/ic[period][signal].std()
# Out:
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 87%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 86%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 87%

# %%
dv.add_field('float_mv')
# Out:
# Query data - query...
# 当前请求query_lb_dailyindicator...
# {'fields': 'symbol,trade_date,float_mv'}
# 下载进度287/1336.
# 下载进度574/1336.
# 下载进度861/1336.
# 下载进度1148/1336.
# Query data - daily fields prepared.
# True

# %%
print(factor2.shape)
# Out:
# (1700, 1336)

# %%
index_member = dv.get_ts("index_member")
type(index_member)
print(index_member.shape)
# Out:
# (1700, 1336)

# %%
from jaqs_fxdayu.research.signaldigger import process
from jaqs_fxdayu.research.signaldigger.process import neutralize


factor_dict = dict()
index_member = dv.get_ts("index_member")

for name in ['factor2','factor5','factor10']:
    signal = dv.get_ts(name) # 调整符号
    process.winsorize(factor_df=signal,alpha=0.05,index_member=index_member)#去极值
    
#     signal = process.rank_standardize(signal,index_member) #因子在截面排序并归一化到0-1(只保留排序信息)
#     # 行业市值中性化
    signal = neutralize(signal,
                                group=dv.get_ts("sw1"),# 行业分类标准
    #                            float_mv = dv.get_ts("float_mv"), #流通市值 可为None 则不进行市值中性化
   #                             index_member=index_member,# 是否只处理时只考虑指数成份股
                                )
    signal = process.standardize(signal,index_member) #z-score标准化 保留排序信息和分布信息
    factor_dict[name] = signal

# %%
props = {
    'price':dv.get_ts("close_adj"),
    'high':dv.get_ts("high_adj"), # 可为空
    'low':dv.get_ts("low_adj"),# 可为空
    'ret_type': 'return',#可选参数还有upside_ret/downside_ret 则组合因子将以优化潜在上行、下行空间为目标
    #'benchmark_price': dv.data_benchmark,  # 为空计算的是绝对收益　不为空计算相对收益
    'period': 20, # 20天的持有期
    'mask': mask,
    'can_enter': can_enter,
    'can_exit': can_exit,
    'forward': True,
    'commission': 0.0008,
    "covariance_type": "shrink",  # 协方差矩阵估算方法 还可以为"simple"
    "rollback_period": 250}  # 滚动窗口天数

comb_factors = dict()
for method in ["equal_weight","ic_weight","ir_weight","max_IR","max_IC"]:
    signal = multi_factor.combine_factors(factor_dict,
                                                        standardize_type="rank",
                                                        winsorization=False,
                                                        weighted_method=method,
                                                        props=props)
    #z-score标准化
    comb_factors[method] = process.standardize(signal,index_member)
# Out:
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 86%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 86%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 86%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 86%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 86%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 86%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 86%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 86%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 86%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 86%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 86%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 86%

# %%
period = 20
ic_20  =   multi_factor.get_factors_ic_df(comb_factors,
                                          price=dv.get_ts("close_adj"),
                                          high=dv.get_ts("high_adj"), # 可为空
                                          low=dv.get_ts("low_adj"),# 可为空
                                          n_quantiles=5,# quantile分类数
                                          mask=mask,# 过滤条件
                                          can_enter=can_enter,# 是否能进场
                                          can_exit=can_exit,# 是否能出场
                                          period=period,# 持有期
                                          #benchmark_price=dv.data_benchmark, # 基准价格 可不传入，持有期收益（return）计算为绝对收益
                                          commission = 0.0008,
                                          )
# Out:
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 86%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 73%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 73%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 73%
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 85%

# %%
ic_20_mean = dict()
ic_20_std = dict()
ir_20 = dict()
for name in ic_20.columns:    
    ic_20_mean[name]=ic_20[name].loc[start:].mean()
    ic_20_std[name]=ic_20[name].loc[start:].std()
    ir_20[name] = ic_20_mean[name]/ic_20_std[name]

# %%
import datetime

trade_date = pd.Series(ic_20.index)
trade_date = trade_date.apply(lambda x: datetime.datetime.strptime(str(x), '%Y%m%d'))
ic_20.index = trade_date

# %%
pd.Series(ic_20_mean).plot(kind="barh",xerr=pd.Series(ic_20_std),figsize=(15,5))

# %%
pd.Series(ir_20).plot(kind="barh",figsize=(15,5))

# %%
obj = SignalDigger(output_folder='./output/样本内三组合/20',
                   output_format='pdf')
obj.process_signal_before_analysis(signal=comb_factors["max_IR"],
                                   price=dv.get_ts("close_adj"),
                                   high=dv.get_ts("high_adj"), # 可为空
                                   low=dv.get_ts("low_adj"),# 可为空
                                   n_quantiles=5,# quantile分类数
                                   mask=mask,# 过滤条件
                                   can_enter=can_enter,# 是否能进场
                                   can_exit=can_exit,# 是否能出场
                                   period=20,# 持有期
                                   #benchmark_price=dv.data_benchmark, # 基准价格 可不传入，持有期收益（return）计算为绝对收益
                                   commission = 0.0008,
                                   )
obj.create_full_report()
plt.show()
# Out:
# Nan Data Count (should be zero) : 0;  Percentage of effective data: 73%
#
#
# Value of signals of Different Quantiles Statistics
#                min       max      mean       std   count    count %
# quantile
# 1        -1.729975 -0.596242 -1.379679  0.202021  334128  20.033624
# 2        -1.369134  0.108690 -0.685357  0.200230  333569  20.000108
# 3        -0.723408  0.821191  0.005670  0.199986  333563  19.999748
# 4        -0.087392  1.299432  0.696355  0.199666  333569  20.000108
# 5         0.703987  1.729975  1.386256  0.199135  333007  19.966412
# Figure saved: F:\output\样本内三组合\20\returns_report.pdf
# Information Analysis
#                  ic
# IC Mean       0.066
# IC Std.       0.071
# t-stat(IC)   34.673
# p-value(IC)   0.000
# IC Skew      -0.071
# IC Kurtosis   1.839
# Ann. IR       0.924
# Figure saved: F:\output\样本内三组合\20\information_report.pdf
